# %% [markdown]
# #Creating Preliminary Comparison Table

# %%
from google.colab import drive
from pathlib import Path

drive.mount('/content/drive')

# IMPORTANT:
# Use the EXACT same project path from 01_dataset_preparation.ipynb
PROJECT_DIR = Path(
    "/content/drive/MyDrive/e23-co5430-Surface-Defect-Detection"
)

print("Project exists:", PROJECT_DIR.exists())
print("Project path:", PROJECT_DIR)
# Out:
# Mounted at /content/drive
# Project exists: True
# Project path: /content/drive/MyDrive/e23-co5430-Surface-Defect-Detection

# %%
import pandas as pd

comparison_data = [
    {
        "Model": "Baseline CNN",
        "Accuracy": 0.9444,
        "Macro Precision": 0.9445,
        "Macro Recall": 0.9444,
        "Macro F1": 0.9442
    },
    {
        "Model": "MobileNetV2 Frozen",
        "Accuracy": 0.9963,
        "Macro Precision": 0.9964,
        "Macro Recall": 0.9963,
        "Macro F1": 0.9963
    }
]

comparison_df = pd.DataFrame(comparison_data)

display(comparison_df)
# Out:
#                 Model  Accuracy  Macro Precision  Macro Recall  Macro F1
# 0        Baseline CNN    0.9444           0.9445        0.9444    0.9442
# 1  MobileNetV2 Frozen    0.9963           0.9964        0.9963    0.9963

# %%
COMPARISON_DIR = PROJECT_DIR / "results" / "comparison"

COMPARISON_DIR.mkdir(
    parents=True,
    exist_ok=True
)

comparison_df.to_csv(
    COMPARISON_DIR / "model_comparison_preliminary.csv",
    index=False
)

print("Saved successfully!")
print(
    "Location:",
    COMPARISON_DIR / "model_comparison_preliminary.csv"
)
# Out:
# Saved successfully!
# Location: /content/drive/MyDrive/e23-co5430-Surface-Defect-Detection/results/comparison/model_comparison_preliminary.csv
